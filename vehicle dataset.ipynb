# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings("ignore") 
df=pd.read_csv(r'C:\Users\acer\Documents\Otherrs\exp1_14drivers_14cars_dailyRoutes.csv') 
df.head()
# Out:
#       TIMESTAMP       MARK  MODEL  CAR_YEAR ENGINE_POWER AUTOMATIC VEHICLE_ID  \
# 0  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 1  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 2  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 3  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
# 4  1.502903e+12  chevrolet  agile    2011.0          1,4         n       car1
#
#    BAROMETRIC_PRESSURE(KPA)  ENGINE_COOLANT_TEMP FUEL_LEVEL  ... THROTTLE_POS  \
# 0                     100.0                 80.0     48,60%  ...          25%
# 1                     100.0                 80.0     48,60%  ...          25%
# 2                     100.0                 80.0     48,60%  ...          25%
# 3                     100.0                 80.0     48,60%  ...          25%
# 4                     100.0                 80.0     48,60%  ...          25%
#
# ...

# %%
df.describe()
# Out:
#           TIMESTAMP      CAR_YEAR  BAROMETRIC_PRESSURE(KPA)  \
# count  4.751400e+04  47459.000000              10212.000000
# mean   1.503236e+12   2010.807560                 96.404328
# std    1.570499e+09      2.933067                  2.865433
# min    1.499536e+12   2003.000000                 89.000000
# 25%    1.502968e+12   2009.000000                 95.000000
# 50%    1.503684e+12   2011.000000                 96.000000
# 75%    1.504179e+12   2012.000000                100.000000
# max    1.505479e+12   2016.000000                101.000000
#
#        ENGINE_COOLANT_TEMP  AMBIENT_AIR_TEMP    ENGINE_RPM  \
# count         33964.000000       3619.000000  33859.000000
# mean             81.772023         27.617298   1517.803391
# std              10.910737          4.289063    613.937502
# min              22.000000         12.000000    438.000000
# 25%              78.000000         27.000000    906.000000
# 50%              85.000000         27.000000   1487.000000
# ...

# %%
df.tail()
# Out:
#        TIMESTAMP MARK MODEL  CAR_YEAR ENGINE_POWER AUTOMATIC VEHICLE_ID  \
# 60434        NaN  NaN   NaN       NaN          NaN       NaN        NaN
# 60435        NaN  NaN   NaN       NaN          NaN       NaN        NaN
# 60436        NaN  NaN   NaN       NaN          NaN       NaN        NaN
# 60437        NaN  NaN   NaN       NaN          NaN       NaN        NaN
# 60438        NaN  NaN   NaN       NaN          NaN       NaN        NaN
#
#        BAROMETRIC_PRESSURE(KPA)  ENGINE_COOLANT_TEMP FUEL_LEVEL  ...  \
# 60434                       NaN                  NaN        NaN  ...
# 60435                       NaN                  NaN        NaN  ...
# 60436                       NaN                  NaN        NaN  ...
# 60437                       NaN                  NaN        NaN  ...
# 60438                       NaN                  NaN        NaN  ...
#
#       THROTTLE_POS  DTC_NUMBER  TROUBLE_CODES  TIMING_ADVANCE EQUIV_RATIO MIN  \
# ...

# %%
df.isna() #true= null, false= data is present #checking null values
# Out:
#        TIMESTAMP   MARK  MODEL  CAR_YEAR  ENGINE_POWER  AUTOMATIC  VEHICLE_ID  \
# 0          False  False  False     False         False      False       False
# 1          False  False  False     False         False      False       False
# 2          False  False  False     False         False      False       False
# 3          False  False  False     False         False      False       False
# 4          False  False  False     False         False      False       False
# ...          ...    ...    ...       ...           ...        ...         ...
# 60434       True   True   True      True          True       True        True
# 60435       True   True   True      True          True       True        True
# 60436       True   True   True      True          True       True        True
# 60437       True   True   True      True          True       True        True
# 60438       True   True   True      True          True       True        True
#
# ...

# %%
df.isna().sum() # total null values
# Out:
# TIMESTAMP                      12925
# MARK                           12980
# MODEL                          12980
# CAR_YEAR                       12980
# ENGINE_POWER                   12980
# AUTOMATIC                      12980
# VEHICLE_ID                     12925
# BAROMETRIC_PRESSURE(KPA)       50227
# ENGINE_COOLANT_TEMP            26475
# FUEL_LEVEL                     57445
# ENGINE_LOAD                    29467
# AMBIENT_AIR_TEMP               56820
# ENGINE_RPM                     26580
# INTAKE_MANIFOLD_PRESSURE       35350
# MAF                            48611
# LONG TERM FUEL TRIM BANK 2     47369
# FUEL_TYPE                      40434
# AIR_INTAKE_TEMP                26087
# FUEL_PRESSURE                  60301
# SPEED                          13910
# SHORT TERM FUEL TRIM BANK 2    47369
# SHORT TERM FUEL TRIM BANK 1    22844
# ENGINE_RUNTIME                 48537
# THROTTLE_POS                   26580
# DTC_NUMBER                     13297
# ...

# %%
df.isnull().sum()
# Out:
# TIMESTAMP                      12925
# MARK                           12980
# MODEL                          12980
# CAR_YEAR                       12980
# ENGINE_POWER                   12980
# AUTOMATIC                      12980
# VEHICLE_ID                     12925
# BAROMETRIC_PRESSURE(KPA)       50227
# ENGINE_COOLANT_TEMP            26475
# FUEL_LEVEL                     57445
# ENGINE_LOAD                    29467
# AMBIENT_AIR_TEMP               56820
# ENGINE_RPM                     26580
# INTAKE_MANIFOLD_PRESSURE       35350
# MAF                            48611
# LONG TERM FUEL TRIM BANK 2     47369
# FUEL_TYPE                      40434
# AIR_INTAKE_TEMP                26087
# FUEL_PRESSURE                  60301
# SPEED                          13910
# SHORT TERM FUEL TRIM BANK 2    47369
# SHORT TERM FUEL TRIM BANK 1    22844
# ENGINE_RUNTIME                 48537
# THROTTLE_POS                   26580
# DTC_NUMBER                     13297
# ...

# %%
sns.displot(df['MODEL'])

# %%
sns.boxplot(df['TIMESTAMP'])
# Out:
# <Axes: >

# %%
df.isna().sum()*100/df.shape[0]
# Out:
# TIMESTAMP                      21.385198
# MARK                           21.476199
# MODEL                          21.476199
# CAR_YEAR                       21.476199
# ENGINE_POWER                   21.476199
# AUTOMATIC                      21.476199
# VEHICLE_ID                     21.385198
# BAROMETRIC_PRESSURE(KPA)       83.103625
# ENGINE_COOLANT_TEMP            43.804497
# FUEL_LEVEL                     95.046245
# ENGINE_LOAD                    48.754943
# AMBIENT_AIR_TEMP               94.012144
# ENGINE_RPM                     43.978226
# INTAKE_MANIFOLD_PRESSURE       58.488724
# MAF                            80.429855
# LONG TERM FUEL TRIM BANK 2     78.374890
# FUEL_TYPE                      66.900511
# AIR_INTAKE_TEMP                43.162528
# FUEL_PRESSURE                  99.771671
# SPEED                          23.014941
# SHORT TERM FUEL TRIM BANK 2    78.374890
# SHORT TERM FUEL TRIM BANK 1    37.796787
# ENGINE_RUNTIME                 80.307417
# ...

# %%
round(df.isna().sum()*100/df.shape[0]) # percentage of missing values
# Out:
# TIMESTAMP                       21.0
# MARK                            21.0
# MODEL                           21.0
# CAR_YEAR                        21.0
# ENGINE_POWER                    21.0
# AUTOMATIC                       21.0
# VEHICLE_ID                      21.0
# BAROMETRIC_PRESSURE(KPA)        83.0
# ENGINE_COOLANT_TEMP             44.0
# FUEL_LEVEL                      95.0
# ENGINE_LOAD                     49.0
# AMBIENT_AIR_TEMP                94.0
# ENGINE_RPM                      44.0
# INTAKE_MANIFOLD_PRESSURE        58.0
# MAF                             80.0
# LONG TERM FUEL TRIM BANK 2      78.0
# FUEL_TYPE                       67.0
# AIR_INTAKE_TEMP                 43.0
# FUEL_PRESSURE                  100.0
# SPEED                           23.0
# SHORT TERM FUEL TRIM BANK 2     78.0
# SHORT TERM FUEL TRIM BANK 1     38.0
# ENGINE_RUNTIME                  80.0
# THROTTLE_POS                    44.0
# DTC_NUMBER                      22.0
# ...

# %%
round(df.isna().sum()*100/df.shape[0],2)
# Out:
# TIMESTAMP                      21.39
# MARK                           21.48
# MODEL                          21.48
# CAR_YEAR                       21.48
# ENGINE_POWER                   21.48
# AUTOMATIC                      21.48
# VEHICLE_ID                     21.39
# BAROMETRIC_PRESSURE(KPA)       83.10
# ENGINE_COOLANT_TEMP            43.80
# FUEL_LEVEL                     95.05
# ENGINE_LOAD                    48.75
# AMBIENT_AIR_TEMP               94.01
# ENGINE_RPM                     43.98
# INTAKE_MANIFOLD_PRESSURE       58.49
# MAF                            80.43
# LONG TERM FUEL TRIM BANK 2     78.37
# FUEL_TYPE                      66.90
# AIR_INTAKE_TEMP                43.16
# FUEL_PRESSURE                  99.77
# SPEED                          23.01
# SHORT TERM FUEL TRIM BANK 2    78.37
# SHORT TERM FUEL TRIM BANK 1    37.80
# ENGINE_RUNTIME                 80.31
# THROTTLE_POS                   43.98
# DTC_NUMBER                     22.00
# ...

# %%
df.drop(columns=['MODEL','SPEED','DAYS_OF_WEEK']) #Drop th particular column
# Out:
#           TIMESTAMP       MARK  CAR_YEAR ENGINE_POWER AUTOMATIC VEHICLE_ID  \
# 0      1.502903e+12  chevrolet    2011.0          1,4         n       car1
# 1      1.502903e+12  chevrolet    2011.0          1,4         n       car1
# 2      1.502903e+12  chevrolet    2011.0          1,4         n       car1
# 3      1.502903e+12  chevrolet    2011.0          1,4         n       car1
# 4      1.502903e+12  chevrolet    2011.0          1,4         n       car1
# ...             ...        ...       ...          ...       ...        ...
# 60434           NaN        NaN       NaN          NaN       NaN        NaN
# 60435           NaN        NaN       NaN          NaN       NaN        NaN
# 60436           NaN        NaN       NaN          NaN       NaN        NaN
# 60437           NaN        NaN       NaN          NaN       NaN        NaN
# 60438           NaN        NaN       NaN          NaN       NaN        NaN
#
# ...
